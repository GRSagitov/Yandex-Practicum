# %% [markdown]
# <a href="https://colab.research.google.com/github/GRSagitov/Yandex-Practicum/blob/main/PET_PROJECT_3_%D0%AF%D0%BD%D0%B4%D0%B5%D0%BA%D1%81_%D0%9C%D0%B0%D1%80%D1%88%D1%80%D1%83%D1%82_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Проект посвящён Яндекс.Маршрутам и состоит из четырёх заданий. Текущая версия Яндекс Маршрутов отличается от версии из прошлого проекта. Теперь в приложении можно заказать каршеринг.
#
# 🚘 Каршеринг: задания 1–3
#
# Сначала предстоит протестировать каршеринг: составить тестовую документацию, выполнить проверки, завести баг-репорты.
#
# Макеты: https://www.figma.com/file/fPw1Xj2dYJy5mdyCg2jduh/Яндекс-Маршруты?node-id=2-18586&p=f&t=5hMAjMC5GwSXOAOg-0
#
# Требования: https://praktikum.notion.site/74dd6e68fda34387ac4d43137a601c6e
#
# Тестовый стенд динамический. Сохранил на сервисе Wayback Machine.
#
# https://web.archive.org/web/20250921193114/https://c3ff4b72-c839-46fc-b2ea-dfcd94293a7b.serverhub.praktikum-services.ru/

# %% [markdown]
# **Часть 1. Подготовить чек-лист на вёрстку полей.**
#
# Изучить требования и макеты. Выбрать один тариф: например, «Роскошный». Если требования и макеты не сходятся — ориентироваться на требования.
#
# Составить чек-лист на вёрстку следующих блоков:
#
# 1. Форма бронирования;
# 2. Элементы на навигационной карте: это иконки автомобилей и действия с ними.

# %% [markdown]
# **Предварительная работа**
#
# 1. Внимательно изучить макеты каршеринга в Figma — вкладка Marshruti car sharing.
# 2. В макетах каршеринга не хватает блока «Требования к заказу». Но практически аналогичные макеты для «Требований к заказу» лежат на вкладке с такси: Marshruti taxi → UI-kit.
#
# Так вышло, потому что коллеги-дизайнеры ещё не успели подготовить UI kit для каршеринга. Так бывает.
#
# Вёрстка элементов (например, чекбоксов) в такси и каршеринге одинаковая, отличаются только тарифы и текст. Подробнее о работе панели «Требования к заказу» в каршеринге можно прочитать в текстовых требованиях.

# %% [markdown]
# ![2d_sprint_project_1.png](data:image/png;base64,...)

# %% [markdown]
# **Составление чек-листа:**
#
# Достаточно выбрать только один тариф и составить чек-лист, по которому будет тестироваться вёрстка формы бронирования и вёрстка элементов на навигационной карте.
#
# Нужно учитывать орфографию, расположение элементов, их внешний вид.

# %% [markdown]
# ![marshruty_1_1.png](data:image/png;base64,...)

# %% [markdown]
# **Важно!**
#
# ✔️ *У полей «Добавить права» и «Способ оплаты» есть разные состояния. Например, у поля «Добавить права» таких состояний два: документы прошли верификацию; документы не прошли верификацию.*
#
# ✔️ *Окна «Машина забронирована», «Вы уверены, что хотите отменить поездку?» и «Поездка отменена» тоже нужно покрыть тестами.*
#
# ✔️ *Иконки машин — тоже часть вёрстки. Например, по требованиям иконка ближайшей машины увеличивается и над ней появляется чёрная плашка с маркой.*
#
# ❌ *Не нужно покрывать тестами валидацию полей.*
#
# ❌ *Не нужно покрывать тестами вёрстку окон «Добавление прав», «Способ оплаты», «Добавление карты». Это значит, что тебе не надо нажимать на поля «Добавить права» и «Способ оплаты» и «проваливаться» дальше, в следующие окна.*

# %% [markdown]
# **Часть 2. Подготовить чек-лист и тест-кейсы на логику работы окон**
#
# Составить следующую тестовую документацию:
# 1. Чек-лист на логику окон «Способ оплаты» и «Добавление карты»,
# 2. Тест-кейсы на кнопку «Забронировать».
#
#
# **Предварительная работа:**
#
# 1. Для чек-листа изучи такие пункты требований: «Поле „Способ оплаты“» и «Окно „Добавление карты“».
# 2. Для тест-кейсов на кнопку «Забронировать» — см. пункт требований «Кнопка „Забронировать“».

# %% [markdown]
# ![2d_sprint_project_2_2.png](data:image/png;base64,...)

# %% [markdown]
# **Составление чек-листа:**
#
# 1. Составь чек-лист, по которому будешь проверять логику окон «Способ оплаты» и «Добавление карты».
# 2. Там, где необходимо, используй технику разбиения на классы эквивалентности и выделения граничных значений. Отправлять КЭ и ГЗ ревьюеру не нужно, это только для тебя.
# 3. Не забудь про позитивные и негативные проверки.
#
# **Подготовка тест-кейсов:**
#
# 1. Составь тест-кейсы на логику работы кнопки «Забронировать».
# 2. Не забудь про позитивные и негативные проверки.
# 3. Пропиши предусловия.
#
# **Важно: **
#
# На кнопке «Забронировать» указаны расстояние и время в пути. Например: «Маршрут составит 3 км и займёт 4 мин.» Тебе не нужно проверять, правильно ли рассчитаны эти данные.
#
# **Часть 3. Протестировать приложение и завести баг-репорты**
#
# Запускаю тестовый стенд и проверяю приложение по своей документации. Если обнаруживаю ошибки, добавляю баг-репорты в Google Таблицу.
#
# **Тестирование:**
#
# 1. Протестировать вёрстку по своему чек-листу. Использовать два окружения:
# * Яндекс Браузер, разрешение экрана 800×600;
# * Firefox, разрешение экрана 1920×1080.
# Для подбора верного разрешения использую DevTools.
# 2. Протестирую логику по своему чек-листу и тест-кейсам. Для тестов использую только одно окружение.
# 3. При тестировании, отмечаю результаты выполнения проверок: PASSED, FAILED, BLOCKED или SKIPPED (англ. «пропущен»).
#
# **Отчет:**
#
# https://docs.google.com/document/d/10-cUKOXmm5QHdnAMtjJCW3O1J1Rafkg1CfM2-8sBwYI/edit?tab=t.0
#
# **Тест-сьют и Баг-репорты:** https://docs.google.com/spreadsheets/d/1YpiDJZZpH1QMHoCAc0xnX6FcSbUUNVfMMngvTz4dVsc/edit?gid=977751969#gid=977751969
#
# **Комментарий ревьюера:**
#
# Привет, Габдула!
# Работа принята! Ты молодец! Получился классный проект, к которому ты сможешь возвращаться для повторения полученных знаний.
# Желаю успехов в дальнейшем обучении!
