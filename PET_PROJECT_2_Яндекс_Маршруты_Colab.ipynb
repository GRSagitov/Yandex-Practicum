# %% [markdown]
# <a href="https://colab.research.google.com/github/GRSagitov/Yandex-Practicum/blob/main/PET_PROJECT_2_%D0%AF%D0%BD%D0%B4%D0%B5%D0%BA%D1%81_%D0%9C%D0%B0%D1%80%D1%88%D1%80%D1%83%D1%82%D1%8B_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Что нужно сделать.**
#
# В рамках проекта этого спринта ты поработаешь с Яндекс Маршрутами. Это сервис, который строит маршруты для транспорта разных видов, рассчитывает время и стоимость поездки.
#
# Вот ссылка на стенд: https://qa-routes.praktikum-services.ru/
#
#
# **Задача:**
# 1. Протестировать валидацию полей ввода времени и адресов в форме.
# 2. Протестировать логику расчёта стоимости и времени поездки на собственном автомобиле.
#
#
# **Часть 1. Тестирование валидации полей в форме**
#
#
# **Что нужно сделать.**
#
# В требованиях к Яндекс.Маршрутам есть таблица с ограничениями на ввод в поля формы.
#
# Ссылка на требования: https://docs.google.com/document/d/1tIs3KqK79vGR60EoGiDKLavvgsj0cjjrdSRK3AFdY6g

# %% [markdown]
# ![image-2_4_1744588803.png](data:image/png;base64,...)

# %% [markdown]
# **Валидация формы работает так:** в случае корректного ввода появляется расчёт времени и стоимости поездки. В случае некорректного ввода появляется сообщение об ошибке.
#
# Нужно проверить, что в реализации применены все требования к полям и валидация проходит так, как задумано. При этом проверять корректность расчётов не нужно: это другой объект тестирования.
#
# *В поля «Откуда» и «Куда» можно вводить только ограниченное количество адресов из таблицы в требованиях: Усачева, 3; Комсомольский проспект, 18; Зубовский бульвар, 37; М. Пироговская, 25; Хамовнический Вал, 34; Фрунзенская набережная, 46; 3-я Фрунзенская улица, 12.*
#
# **В рамках задания нужно:**
#
# 1. Провести тест-анализ требований на валидацию полей. Если найдёшь серые зоны, обратись за разъяснением к преподавателю.
# 2. Создать набор тест-кейсов на проверку валидации полей формы Яндекс Маршрутов. Примени техники тест-дизайна: классы эквивалентности и граничные значения.
# 3. Протестировать валидацию полей и завести баг-репорты, если есть баги.
#
# **Что в итоге.**
#
# Вот что должно появиться после завершения тестирования:
# 1. Таблица с классами эквивалентности и граничными значениями;
# 2. Набор тест-кейсов на валидацию полей;
# 3. Баг-репорты.

# %% [markdown]
# **Часть 2. Тестирование расчета стоимости и времени поездки**
#
# **Что нужно сделать**
#
# Яндекс Маршруты рассчитывают время и стоимость поездки, в том числе на своём автомобиле. В [требованиях](https://docs.google.com/document/d/1tIs3KqK79vGR60EoGiDKLavvgsj0cjjrdSRK3AFdY6g/edit?tab=t.0#heading=h.7j2fbty8r7vb) есть таблицы средней скорости автомобиля и расстояний между адресами, на основе которых должен производиться расчёт времени поездки. По стоимости указано, что за 1 км расход составляет 20 руб.

# %% [markdown]
# ![image-3_5_1744588990.png](data:image/png;base64,...)

# %% [markdown]
# ![image-4_2_1744589015.png](data:image/png;base64,...)

# %% [markdown]
# Необходимо проверить, что приложение верно рассчитывает время и стоимость поездки для собственного автомобиля.
#
# *Время поездки рассчитывается по формуле t (мин) = (S/V) умножить на 60 (где t — время поездки, S — расстояние, V — средняя скорость);
# Стоимость поездки рассчитывается по формуле: Рr = S умножить на P (где Рr — итоговая стоимость поездки, S — расстояние, Р — стоимость 1 км).
# Важно! Средняя скорость для расчёта берётся по времени начала поездки.*
#
# **В рамках задания нужно:**
# 1. Провести тест-анализ требований расчёта времени и стоимости маршрута на собственном автомобиле. Если найдёшь серые зоны, обратись за разъяснением к преподавателю.
# 2. Применить технику тест-дизайна «Классы эквивалентности» и создать набор тест-кейсов на проверку правильности расчёта времени и стоимости поездки на собственном автомобиле.
# 3. Протестировать расчёты и завести баг-репорты, если есть баги.
#
# **Что в итоге.**
#
# Вот что должно появиться после завершения тестирования:
# 1. Таблица с классами эквивалентности и граничными значениями;
# 2. Набор тест-кейсов на валидацию полей;
# 3. Баг-репорты.
#
# **Итоговая работа:** https://docs.google.com/spreadsheets/d/1rWa23XZHOaNEjxsCV3yqSjA35hQIzl13Ym2jHgst_TM/edit?gid=483862348#gid=483862348
#
# **Комментарий ревьюера:**
# Габдула, привет.
# Спасибо за доработку, давай смотреть что получилось.
#
# {КЭ}
# Замечаний в этой части не осталось.
# Таблицу КЭ принимаю.
#
# {Тест-кейсы}
# Расчёты времени и стоимости
# В названии кейсов 61 и 62 нужно уточнить, какие именно мы проверяем расчёты — стоимости и продолжительности.
# В остальном критичных замечаний не осталось.
# Тест-кейсы — зачёт.
#
# {Баг-репорты}
# Баг-репорты принимаю.
# Габдула, у тебя получился отличный проект, за который ты получаешь зачёт.
# Поздравляю и желаю успехов в твоём дальнейшем обучении!
