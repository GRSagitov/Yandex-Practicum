# %% [markdown]
# <a href="https://colab.research.google.com/github/GRSagitov/Yandex-Practicum/blob/main/PET_PROJECT_6_%D0%AF%D0%BD%D0%B4%D0%B5%D0%BA%D1%81_%D0%A1%D0%B0%D0%BC%D0%BE%D0%BA%D0%B0%D1%82__Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Яндекс.Самокат. Это сервис, который позволяет арендовать электрический самокат на несколько дней.**
#
# **Задачи:**
# 1. Тестирование веб-приложения.
# 2. Тестирование мобильного приложения.
# 3. Тестирование API.
#
# **Задание 1: Веб-приложение Яндекс.Самокат**
#
# **Что нужно сделать:**
# 1. Обратить внимание на техническую информацию при запуске приложения — в ней описаны все доступы к серверу, БД и адреса API.
# 2. Изучить требования. Требования к приложению — [здесь](https://code.s3.yandex.net/qa/files/requirements_web_app_1.1.pdf).
# 3. Составить чек-лист по требованиям к экрану «Статус заказа».
# 4. Для экрана «Сделать заказ» составить проверки на валидацию полей. Заполнить их в виде таблицы по шаблону.
# 5. Провести тестирование всей функциональности не только по получившимся чек-листам и таблицам, но и по остальным макетам и требованиям. Проверять главную страницу (лендинг) не нужно. Макеты лежат в Figma [здесь](https://www.figma.com/file/vHgTVzFac8zyxhMZ2o4b2m/web). Результаты помести на вкладку «Задание 1: баги вне тестовой документации».
#
# **Оформление результатов:**
# * В чек-листе должны быть результаты выполненных тестов и заведённые баг-репорты.
# * Баги, найденные вне тестовой документации, нужно поместить в отдельную вкладку не смешивая с другими баг-репортами.
#
# **Задание 2: Мобильное приложение Яндекс.Самокат**
#
# **Приложение:** https://code.s3.yandex.net/qa/files/scooter-v2.0.apk
#
# **Что нужно сделать**
#
# 1. Обратить внимание на техническую информацию при запуске приложения.
# 2. Изучить требования к приложению — [здесь](https://code.s3.yandex.net/qa/files/requirements_mob_app.pdf).
# 3. Спроектировать тест-кейсы и протестировать функциональность, которая выделена жирным шрифтом. Не забыть написать кейсы и на вёрстку по макетам к этой функциональности. Макеты лежат в Figma [здесь](https://www.figma.com/file/kqLqPvSvjLVLomkdadkAnk/mobile).
#
# **Оформление результатов:**
# * Тест-кейсы должны быть приложены в таблицу.
# * В тест кейсах должны быть результаты проверок и заведённые баг-репорты, если они есть.
#
# **Задание 3: API приложения Яндекс.Самокат**
#
# **Что нужно сделать**
#
# 1. Обратить внимание на техническую информацию при запуске приложения.
# 2. Изучить требования к бэкенду и документацию к API. Требования к бэкенду — [здесь](https://code.s3.yandex.net/qa/files/requirements_backend.pdf).
# 3. Разработать чек-лист и протестировать API по требованиям, которые выделены жирным шрифтом.
#
# **Оформление результатов:**
#
# * Приложить чек-лист проверки API в шаблон в таблицу. В чек-листе должны быть результаты выполнения тестов и заведённые баг-репорты.
#
# **Отчет:**
#
# Все проверки и баг репорты собраны в [одной таблице](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=943703744#gid=943703744). Также для упрощения
# работы пришлось переработать все шаблоны таблиц.
# Ниже представлены прямые ссылки на все листы таблицы.
#
# **Задание 1: Веб-приложение Яндекс.Самокат**
# 1. [Чек-лист ](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=943703744#gid=943703744&range=A:A)
# 2. [Данные валидации](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=1540465171#gid=1540465171&range=A:A)
# 3. [Баги вне тестовой документации ](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=1539613303#gid=1539613303&range=A:A)
# 4. [Баг-репорт](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=310969759#gid=310969759&range=A:A)
#
# **Задание 2: Мобильное приложение Яндекс.Самокат**
# 1. [Тест-кейсы ](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=424948590#gid=424948590&range=A:A)
# 2. [Баг-репорт](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=2103363814#gid=2103363814&range=A:A)
#
# **Задание 3: API приложения Яндекс.Самокат**
# 1. [Чек-лист](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=336872680#gid=336872680&range=A:A)
# 2. [Баг-репорт](https://docs.google.com/spreadsheets/d/19hrs86aEGtcabap7vyHZbjJhZ4yjd2QIYx8oo1ofK-k/edit?gid=1750164123#gid=1750164123&range=A:A)
#
# **Комментарий ревьюера:**
#
# Габдула, привет еще раз!
#
# Спаибо за детальные ответы на каждый мой комментарий! Зачет! Ниже оставил комментарии насчет проверок обязательности заполения полей и поля "Дата доставки". Просто имей ввиду, что КЭ - это облась данных, поэтому в таком документе не нужно писать "проверить", "ввести", "выбрать". Просто достаточно перечислить вводимые данные по классам, например: прошедшиие даты, сегодняшняя дата, будущие даты и т.д. А так, все ок!
#
# Желаю дальнейших успехов в нашей отрасли!
#
# Чек-лист.
#
# ✅«Отлично»
#
# Молодец, что разбил чек-лист на логические блоки.
# Хорошо, что провел тестирование в разных окружениях.
# Найдено много багов.
#
# Валидация
#
# ⛔️«Нужно исправить»
#
# Проверки "Обязательность (заполненое поле)". Вижу, что ты пишешь, что их оптимизировал, но я все равно их вижу в листе валидации.
#
# Дата доставки. Речь шла только о том, чтобы названия КЭ не были похожи на функциональные проверки. Тем не менее, проверить это поле на выбор завтрашней, вчерашней, сегордняшней даты нужно, составив соответствующие КЭ. Дополнительно  с список КЭ по этому полю можно включить ручной ввод.
#
# Баг-репорты
#
# ✅«Отлично»
#
# Приложены информативные скриншоты.
#
# Задание 2
#
# Тест-кейсы
#
# ✅«Отлично»
#
# Составлено много тест-кейсов, отличное тестовое покрытие
#
# Баг-репорты
#
# ✅«Отлично»
#
# Найдены хорошие баги. Отличное оформление.
#
# Задание 3
#
# Чек-лист
#
#
# ✅«Отлично»
#
#
# Чек-лист полный, замечаний нет.
#
# Баг-репорты
#
# ✅«Отлично»
#
# Найдено много багов, в т.ч. обязательные.
#
# С уважением, твой ревьюер Никита
